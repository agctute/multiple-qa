# %%
import json
data = {}
with open('BinarySEEDBench.json', 'r') as f:
    data = json.load(f)

# %%
questions = [
    "Is there exactly one towel in the image?",
    "Are there exactly two towels in the image?",
    "Are there exactly three towels in the image?",
    "Are there exactly four towels in the image?",
    "Is the building only a hotel?",
    "Is the building only a house?",
    "Is the building only a cabin?",
    "Is the building only a shed?",
    "Is the man only standing with his arms crossed?",
    "Is the man only holding a cell phone?",
    "Is the man in the suit only taking a picture?",
    "Is the man in the suit only talking to someone?",
    "Is the color of the chair on the right side of the image white?",
    "Is the color of the chair on the right side of the image black?",
    "Is the color of the chair on the right side of the image gray?",
    "Is the color of the chair on the right side of the image brown?",
    "Is there exactly one person in the image?",
    "Are there exactly two people in the image?",
    "Are there exactly three people in the image?",
    "Are there exactly four people in the image?",
    "Is there exactly one man on the airplane?",
    "Are there exactly two men on the airplane?",
    "Are there exactly three men on the airplane?",
    "Are there exactly four men on the airplane?",
    "Does one of the men in the car have a short beard?",
    "Does one of the men in the car have a long beard?",
    "Does one of the men in the car have a goatee?",
    "Do any of the men have a beard?",
    "Is there no mouth in the image?",
    "Is there no floor in the image?",
    "Is there no ear in the image?",
    "Is there no toy in the image?",
    "Are the soccer player and the football player teammates?",
    "Is the relationship between the soccer and football player undetermined?"
    "Are the soccer player and the football player opponents?",
    "Are the soccer player and the football player not interacting?",
    "Is the predominant color of the sand on the beach white?",
    "Is the predominant color of the sand on the beach brown?",
    "Is the predominant color of the sand on the beach black?",
    "Is the predominant color of the sand on the beach gray?",
    "Is there a cloudy sky in the background of the image?",
    "Is there a clear blue sky in the background of the image?",
    "Is there a tree in the background of the image?",
    "Is there a building in the background of the image?",
    "Are there exactly three people in the image?",
    "Are there exactly two person in the image?",
    "Is there exactly one person in the image?",
    "Are there exactly four people in the image?",
    "Is there a group of people playing soccer in the image?",
    "Is there a crowd of people watching a live music performance?",
    "Is there a group of people attending a political rally?",
    "Is the main event taking place in the image a street performer playing music while people pass by?",
    "Is the man only wearing a suit and tie?",
    "Is the man only wearing a casual t-shirt?",
    "Is the man only wearing a Hawaiian shirt?",
    "Is the man only wearing a sweater and jeans?",
    "Is the guitar the object in the image with an attribute of 'leather'?",
    "Is the microphone the object in the image with an attribute of 'leather'?",
    "Is the arm the object in the image with an attribute of 'leather'?",
    "Is the shoe the object in the image with an attribute of 'leather'?",
    "Are sparrows not present in the image?",
    "Are hummingbirds not present in the image?",
    "Are white doves not present in the image?",
    "Are multiple bird species present in the image?",
    "Is the main focus of the image a bedroom?",
    "Is the main focus of the image a kitchen?",
    "Is the main focus of the image a living room?",
    "Is the main focus of the image a dining room?",
    "Is there a coffee table in the center of the room?",
    "Is there a desk in the center of the room?",
    "Is there a dining table in the center of the room?",
    "Is there a side table in the center of the room?",
    "Is there a bicycle in the room besides the people and the guitar?",    "Is there a bicycle in the room besides the people and the guitar?",
    "Is there a television in the room besides the people and the guitar?",
    "Is there a bicycle, a television, and a window all in the room besides the people and the guitar?",
    "Is there a window in the room besides the people and the guitar?",
    "Is the man's beard the same length as his hair?",
    "Is the man's beard longer than his hair?",
    "Is the man's hair longer than his beard?",
    "Does the man have no beard?",
    "Is the red car centered in the middle of the image?",
    "Is the red car in the foreground, left side of the image?",
    "Is the red car in the background, right side of the image?",
    "Is the red car in the image?",
    "Is the man in front of the camera?",
    "Is the man beside the camera?",
    "Is the man behind the camera?",
    "Is the man on top of the camera?",
    "Is the refrigerator located next to the dining room table?",
    "Is the refrigerator location undeterminable?",
    "Is there no refrigerator in the image?",
    "Is the refrigerator located in the kitchen area?",
    "Is the woman inside the tent?",
    "Is the woman standing in front of the tent on the left side?",
    "Is the woman standing in front of the tent on the right side?",
    "Is the woman behind the tent?",
    "Is the guitar in the center?",
    "Is the guitar on the left?",
    "Is the guitar on the right?",
    "Is the guitar in the background?",
    "Is there a soccer game going on?",
    "Is there a basketball court in this image?",
    "Is there a person playing volleyball?",
    "Is there a baseball game going on?",
    "Are the group of people sitting on the street homeless?",
    "Are the group of people sitting on the street street performers?",
    "Are the group of people sitting on the street waiting for a parade?",
    "Are the group of people sitting on the street tourists?",
    "Is it not possible to determine the relative position of the woman's lips and her angry face from the information provided?",
    "Are the woman's lips and her angry face close to each other?",
    "Are the woman's lips and her angry face far from each other?",
    "Are the woman's lips and her angry face touching?",
    "Is it not possible to determine the relative position of the woman's hand and face from the information given?",
    "Is the woman's hand on her face?",
    "Are the woman's hand and face far from each other?",
    "Are the woman's hand and face close to each other?",
    "Is the building in the center of the image a train station?",
    "Is the building in the center of the image a shopping mall?",
    "Is the building in the center of the image a residential building?",
    "Is the building in the center of the image a government building?",
    "Is the season winter?",
    "Is the season summer?",
    "Is the season fall?",
    "Is the season spring?",
    "Is the writing on the black background red?",
    "Is the writing on the black background white?",
    "Is the writing on the black background blue?",
    "Is the writing on the black background yellow?",
    "Is the train passing by a pencil fence?",
    "Is the train running on a railroad track made of colored pencils?",
    "Is the train pulling a long row of colored pencils?",
    "Is the train pushing a long row of colored pencils?",
    "Are the letters on the building white?",
    "Are the letters on the building black?",
    "Are the letters on the building red?",
    "Are the letters on the building blue?",
    "Is the letter red?",
    "Is the letter white?",
    "Is the letter blue?",
    "Is the letter green?",
    "Is the sign black?",
    "Is the sign white?",
    "Is the sign red?",
    "Is the sign blue?"
]

# %%
print(len(questions))
print(len(data['test']))
for i in range(len(data['test'])):
    print(data['test'][i]['question'])
    print(questions[i])
#     temp = input()
#     if temp == '':
    data['test'][i]['question'] = questions[i]
#     else:
#         data['test'][i]['question'] = temp
# Out:
# 144
# 144
# Is there exactly one towel in the image?
# Is there exactly one towel in the image?
# Are there exactly two towels in the image?
# Are there exactly two towels in the image?
# Are there exactly three towels in the image?
# Are there exactly three towels in the image?
# Are there exactly four towels in the image?
# Are there exactly four towels in the image?
# Is the building only a hotel?
# Is the building only a hotel?
# Is the building only a house?
# Is the building only a house?
# Is the building only a cabin?
# Is the building only a cabin?
# Is the building only a shed?
# Is the building only a shed?
# Is the man only standing with his arms crossed?
# Is the man only standing with his arms crossed?
# Is the man only holding a cell phone?
# Is the man only holding a cell phone?
# Is the man in the suit only taking a picture?
# Is the man in the suit only taking a picture?
# Is the man in the suit only talking to someone?
# ...

# %%
with open('BinarySEEDBenchVerified.json', 'w') as f:
    json.dump(data, f)

# %%
print(data['test'][143]['question'])
# Out:
# Is the sign blue?
